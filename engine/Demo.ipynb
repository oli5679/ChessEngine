# %%
import alphabeta
# Out:
# Traceback (most recent call last):
#
#   File "/Users/oliver.cairns/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-bc47d05a3a22>", line 1, in <module>
#     import alphabeta
#
#   File "/Users/oliver.cairns/Desktop/code/chess/engine/alphabeta.py", line 26
#     if evaluation
#                  ^
# SyntaxError: invalid syntax

# %%
# %%timeit
engine = alphabeta.Engine(color='white',max_depth=3)

engine.play('c7c5')

engine.play('b8c6')

engine.play('g7g6')

engine.play('c5d4')

engine.play('f8g7')

engine.play('g8f6')

engine.play('e8g8')

engine.play('a7a5')


engine.play('b7c6')
# Out:
# response e2e4
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
# move: c7c5
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . p . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# response g1f3
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . p . . . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
# move: b8c6
# r . b q k b n r
# p p . p p p p p
# . . n . . . . .
# . . p . . . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
#
# response b1c3
# r . b q k b n r
# p p . p p p p p
# . . n . . . . .
# . . p . . . . .
# . . . . P . . .
# . . N . . N . .
# P P P P . P P P
# R . B Q K B . R
# move: g7g6
# r . b q k b n r
# p p . p p p . p
# . . n . . . p .
# . . p . . . . .
# . . . . P . . .
# . . N . . N . .
# P P P P . P P P
# R . B Q K B . R
#
# response d2d4
# r . b q k b n r
# ...

# %%
5.36

# %%
# %%snakeviz
# engine.play('b7c6')

# %%
engine.play('c8a6')

# %%
engine.board

# %%
# %load_ext snakeviz

# %%
# %%snakeviz
# engine.play('f8e8')
